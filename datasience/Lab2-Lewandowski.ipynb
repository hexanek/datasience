# %%
import numpy as np

# %%
import pandas as pd

# %%
fury = pd.read_csv('samochody1tys.csv')

# %%
fury
# Out:
#       id       marka        model  rok_produkcji rodzaj_silnika  \
# 0      0      Nissan  X-Trail III         2014.0         Diesel
# 1      1         BMW       X1 E84         2012.0         Diesel
# 2      2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3      3     Hyundai        i10 I         2008.0        Benzyna
# 4      4  Volkswagen           CC         2010.0         Diesel
# ..   ...         ...          ...            ...            ...
# 995  995  Alfa Romeo          159         2009.0         Diesel
# 996  996       Škoda     Fabia II         2012.0        Benzyna
# 997  997     Renault        Modus         2004.0        Benzyna
# 998  998        Audi        A3 8L         2000.0        Benzyna
# 999  999       Volvo      XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# 0               1600.0  160000.0   75900.0    Dolnośląskie
# 1               2000.0  149000.0   70900.0  Świętokrzyskie
# ...

# %%
dates = pd.date_range('20190101',periods=1000)

# %%
dates
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2021-09-17', '2021-09-18', '2021-09-19', '2021-09-20',
#                '2021-09-21', '2021-09-22', '2021-09-23', '2021-09-24',
#                '2021-09-25', '2021-09-26'],
#               dtype='datetime64[ns]', length=1000, freq='D')

# %%
fury.head()
# Out:
#    id       marka        model  rok_produkcji rodzaj_silnika  \
# 0   0      Nissan  X-Trail III         2014.0         Diesel
# 1   1         BMW       X1 E84         2012.0         Diesel
# 2   2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3   3     Hyundai        i10 I         2008.0        Benzyna
# 4   4  Volkswagen           CC         2010.0         Diesel
#
#    pojemnosc_silnika  przebieg     cena     wojewodztwo
# 0             1600.0  160000.0  75900.0    Dolnośląskie
# 1             2000.0  149000.0  70900.0  Świętokrzyskie
# 2             1600.0   99000.0   9800.0        Opolskie
# 3             1100.0   93000.0  11900.0         Łódzkie
# 4             1968.0  127428.0  49900.0   Wielkopolskie

# %%
fury.tail(3)
# Out:
#       id    marka    model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 997  997  Renault    Modus         2004.0        Benzyna             1200.0
# 998  998     Audi    A3 8L         2000.0        Benzyna             1595.0
# 999  999    Volvo  XC 60 I         2016.0         Diesel             1969.0
#
#      przebieg      cena  wojewodztwo
# 997  168111.0   10900.0      Łódzkie
# 998  226500.0    5400.0  Małopolskie
# 999   13617.0  136900.0  Małopolskie

# %%
fury.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
fury.columns
# Out:
# Index(['id', 'marka', 'model', 'rok_produkcji', 'rodzaj_silnika',
#        'pojemnosc_silnika', 'przebieg', 'cena', 'wojewodztwo'],
#       dtype='object')

# %%
fury.to_numpy()
# Out:
# array([[0, 'Nissan', 'X-Trail III', ..., 160000.0, 75900.0,
#         'Dolnośląskie'],
#        [1, 'BMW', 'X1 E84', ..., 149000.0, 70900.0, 'Świętokrzyskie'],
#        [2, 'Opel', 'Zafira A', ..., 99000.0, 9800.0, 'Opolskie'],
#        ...,
#        [997, 'Renault', 'Modus', ..., 168111.0, 10900.0, 'Łódzkie'],
#        [998, 'Audi', 'A3 8L', ..., 226500.0, 5400.0, 'Małopolskie'],
#        [999, 'Volvo', 'XC 60 I', ..., 13617.0, 136900.0, 'Małopolskie']],
#       dtype=object)

# %%
fury.describe()
# Out:
#                 id  rok_produkcji  pojemnosc_silnika       przebieg  \
# count  1000.000000    1000.000000        1000.000000    1000.000000
# mean    499.500000    2009.009000        2040.065000  132556.677000
# std     288.819436       5.907946        6014.545066   90094.944138
# min       0.000000    1979.000000           1.000000       1.000000
# 25%     249.750000    2005.000000        1500.000000   51750.000000
# 50%     499.500000    2009.000000        1800.000000  149000.000000
# 75%     749.250000    2014.000000        2000.000000  193000.000000
# max     999.000000    2017.000000      191000.000000  647000.000000
#
#                 cena
# count    1000.000000
# mean    51942.181000
# std     70057.918015
# min       650.000000
# 25%     14900.000000
# 50%     27250.000000
# 75%     58900.000000
# max    616000.000000

# %%
fury.T
# Out:
#                             0               1            2        3    \
# id                            0               1            2        3
# marka                    Nissan             BMW         Opel  Hyundai
# model               X-Trail III          X1 E84     Zafira A    i10 I
# rok_produkcji              2014            2012         2004     2008
# rodzaj_silnika           Diesel          Diesel  Benzyna+CNG  Benzyna
# pojemnosc_silnika          1600            2000         1600     1100
# przebieg                 160000          149000        99000    93000
# cena                      75900           70900         9800    11900
# wojewodztwo        Dolnośląskie  Świętokrzyskie     Opolskie  Łódzkie
#
#                              4            5             6          7    \
# id                             4            5             6          7
# marka                 Volkswagen         Fiat        Nissan       Seat
# ...

# %%
fury.sort_index(axis=1, ascending=False)
# Out:
#         wojewodztwo  rok_produkcji rodzaj_silnika  przebieg  \
# 0      Dolnośląskie         2014.0         Diesel  160000.0
# 1    Świętokrzyskie         2012.0         Diesel  149000.0
# 2          Opolskie         2004.0    Benzyna+CNG   99000.0
# 3           Łódzkie         2008.0        Benzyna   93000.0
# 4     Wielkopolskie         2010.0         Diesel  127428.0
# ..              ...            ...            ...       ...
# 995     Małopolskie         2009.0         Diesel  182000.0
# 996       Lubelskie         2012.0        Benzyna   42700.0
# 997         Łódzkie         2004.0        Benzyna  168111.0
# 998     Małopolskie         2000.0        Benzyna  226500.0
# 999     Małopolskie         2016.0         Diesel   13617.0
#
#      pojemnosc_silnika        model       marka   id      cena
# 0               1600.0  X-Trail III      Nissan    0   75900.0
# 1               2000.0       X1 E84         BMW    1   70900.0
# ...

# %%
fury.sort_values(by='cena')
# Out:
#       id          marka                 model  rok_produkcji rodzaj_silnika  \
# 249  249         Daewoo                  Tico         2000.0        Benzyna
# 626  626     Mitsubishi              Colt CJ0         1997.0        Benzyna
# 497  497           Fiat                 Brava         1998.0        Benzyna
# 321  321     Volkswagen              Polo III         1998.0        Benzyna
# 487  487     Mitsubishi              Colt CJ0         2002.0        Benzyna
# ..   ...            ...                   ...            ...            ...
# 410  410            BMW        Seria 7 G11/12         2017.0        Hybryda
# 517  517           Audi                   RS7         2016.0        Benzyna
# 855  855     Land Rover  Range Rover Sport II         2016.0        Benzyna
# 586  586  Mercedes-Benz          Klasa G W463         2013.0        Benzyna
# 405  405  Mercedes-Benz               SL R231         2016.0        Benzyna
#
# ...

# %%
fury['marka']
# Out:
# 0          Nissan
# 1             BMW
# 2            Opel
# 3         Hyundai
# 4      Volkswagen
#           ...
# 995    Alfa Romeo
# 996         Škoda
# 997       Renault
# 998          Audi
# 999         Volvo
# Name: marka, Length: 1000, dtype: object

# %%
fury[0:3]
# Out:
#    id   marka        model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 0   0  Nissan  X-Trail III         2014.0         Diesel             1600.0
# 1   1     BMW       X1 E84         2012.0         Diesel             2000.0
# 2   2    Opel     Zafira A         2004.0    Benzyna+CNG             1600.0
#
#    przebieg     cena     wojewodztwo
# 0  160000.0  75900.0    Dolnośląskie
# 1  149000.0  70900.0  Świętokrzyskie
# 2   99000.0   9800.0        Opolskie

# %%
fury.loc[0]
# Out:
# id                              0
# marka                      Nissan
# model                 X-Trail III
# rok_produkcji                2014
# rodzaj_silnika             Diesel
# pojemnosc_silnika            1600
# przebieg                   160000
# cena                        75900
# wojewodztwo          Dolnośląskie
# Name: 0, dtype: object

# %%
fury.loc[:, ['marka', 'model']]
# Out:
#           marka        model
# 0        Nissan  X-Trail III
# 1           BMW       X1 E84
# 2          Opel     Zafira A
# 3       Hyundai        i10 I
# 4    Volkswagen           CC
# ..          ...          ...
# 995  Alfa Romeo          159
# 996       Škoda     Fabia II
# 997     Renault        Modus
# 998        Audi        A3 8L
# 999       Volvo      XC 60 I
#
# [1000 rows x 2 columns]

# %%
fury.loc[0:10, ['marka', 'model']]
# Out:
#          marka          model
# 0       Nissan    X-Trail III
# 1          BMW         X1 E84
# 2         Opel       Zafira A
# 3      Hyundai          i10 I
# 4   Volkswagen             CC
# 5         Fiat            500
# 6       Nissan      X-Trail I
# 7         Seat      Toledo II
# 8   Volkswagen             CC
# 9       Nissan           Juke
# 10      Toyota  Corolla Seria

# %%
fury.loc[0, ['marka', 'model']]
# Out:
# marka         Nissan
# model    X-Trail III
# Name: 0, dtype: object

# %%
fury.loc[0, 'cena']
# Out:
# 75900.0

# %%
fury.at[0, 'cena']
# Out:
# 75900.0

# %%
fury.iloc[3]
# Out:
# id                         3
# marka                Hyundai
# model                  i10 I
# rok_produkcji           2008
# rodzaj_silnika       Benzyna
# pojemnosc_silnika       1100
# przebieg               93000
# cena                   11900
# wojewodztwo          Łódzkie
# Name: 3, dtype: object

# %%
fury.iloc[3:5, 0:2]
# Out:
#    id       marka
# 3   3     Hyundai
# 4   4  Volkswagen

# %%
fury.iloc[[1, 2, 4], [0, 2]]
# Out:
#    id     model
# 1   1    X1 E84
# 2   2  Zafira A
# 4   4        CC

# %%
fury.iloc[1:3, :]
# Out:
#    id marka     model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 1   1   BMW    X1 E84         2012.0         Diesel             2000.0
# 2   2  Opel  Zafira A         2004.0    Benzyna+CNG             1600.0
#
#    przebieg     cena     wojewodztwo
# 1  149000.0  70900.0  Świętokrzyskie
# 2   99000.0   9800.0        Opolskie

# %%
fury.iloc[:, 1:3]
# Out:
#           marka        model
# 0        Nissan  X-Trail III
# 1           BMW       X1 E84
# 2          Opel     Zafira A
# 3       Hyundai        i10 I
# 4    Volkswagen           CC
# ..          ...          ...
# 995  Alfa Romeo          159
# 996       Škoda     Fabia II
# 997     Renault        Modus
# 998        Audi        A3 8L
# 999       Volvo      XC 60 I
#
# [1000 rows x 2 columns]

# %%
fury.iloc[1, 1]
# Out:
# 'BMW'

# %%
fury.iat[1, 1]
# Out:
# 'BMW'

# %%
fury[fury.cena > 100000]
# Out:
#       id          marka         model  rok_produkcji rodzaj_silnika  \
# 17    17  Mercedes-Benz  Klasa E W213         2017.0         Diesel
# 18    18     Volkswagen     Tiguan II         2017.0         Diesel
# 20    20          Honda       CR-V IV         2017.0        Benzyna
# 21    21  Mercedes-Benz  Klasa E W213         2017.0         Diesel
# 33    33  Mercedes-Benz       CLA CLA         2017.0        Benzyna
# ..   ...            ...           ...            ...            ...
# 957  957          Škoda    Superb III         2016.0        Benzyna
# 967  967           Audi         A6 C7         2017.0         Diesel
# 976  976  Mercedes-Benz  Klasa C W205         2015.0        Benzyna
# 988  988            BMW            M2         2017.0        Benzyna
# 999  999          Volvo       XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena          wojewodztwo
# 17              1950.0       5.0  258709.0              Łódzkie
# ...

# %%
fury2 = fury.copy()

# %%
fury2
# Out:
#       id       marka        model  rok_produkcji rodzaj_silnika  \
# 0      0      Nissan  X-Trail III         2014.0         Diesel
# 1      1         BMW       X1 E84         2012.0         Diesel
# 2      2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3      3     Hyundai        i10 I         2008.0        Benzyna
# 4      4  Volkswagen           CC         2010.0         Diesel
# ..   ...         ...          ...            ...            ...
# 995  995  Alfa Romeo          159         2009.0         Diesel
# 996  996       Škoda     Fabia II         2012.0        Benzyna
# 997  997     Renault        Modus         2004.0        Benzyna
# 998  998        Audi        A3 8L         2000.0        Benzyna
# 999  999       Volvo      XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# 0               1600.0  160000.0   75900.0    Dolnośląskie
# 1               2000.0  149000.0   70900.0  Świętokrzyskie
# ...

# %%
fury3 = fury.reindex(index=dates[0:4], columns=list(fury.columns) + ['E'])

# %%
fury3.loc[dates[0]:dates[1], 'E'] = 1

# %%
fury3
# Out:
#             id marka model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 2019-01-01 NaN   NaN   NaN            NaN            NaN                NaN
# 2019-01-02 NaN   NaN   NaN            NaN            NaN                NaN
# 2019-01-03 NaN   NaN   NaN            NaN            NaN                NaN
# 2019-01-04 NaN   NaN   NaN            NaN            NaN                NaN
#
#             przebieg  cena wojewodztwo    E
# 2019-01-01       NaN   NaN         NaN  1.0
# 2019-01-02       NaN   NaN         NaN  1.0
# 2019-01-03       NaN   NaN         NaN  NaN
# 2019-01-04       NaN   NaN         NaN  NaN

# %%
fury3.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [id, marka, model, rok_produkcji, rodzaj_silnika, pojemnosc_silnika, przebieg, cena, wojewodztwo, E]
# Index: []

# %%
fury3.fillna(value=5)
# Out:
#              id  marka  model  rok_produkcji  rodzaj_silnika  \
# 2019-01-01  5.0      5      5            5.0               5
# 2019-01-02  5.0      5      5            5.0               5
# 2019-01-03  5.0      5      5            5.0               5
# 2019-01-04  5.0      5      5            5.0               5
#
#             pojemnosc_silnika  przebieg  cena  wojewodztwo    E
# 2019-01-01                5.0       5.0   5.0            5  1.0
# 2019-01-02                5.0       5.0   5.0            5  1.0
# 2019-01-03                5.0       5.0   5.0            5  5.0
# 2019-01-04                5.0       5.0   5.0            5  5.0

# %%
pd.isna(fury3)
# Out:
#               id  marka  model  rok_produkcji  rodzaj_silnika  \
# 2019-01-01  True   True   True           True            True
# 2019-01-02  True   True   True           True            True
# 2019-01-03  True   True   True           True            True
# 2019-01-04  True   True   True           True            True
#
#             pojemnosc_silnika  przebieg  cena  wojewodztwo      E
# 2019-01-01               True      True  True         True  False
# 2019-01-02               True      True  True         True  False
# 2019-01-03               True      True  True         True   True
# 2019-01-04               True      True  True         True   True

# %%
fury.mean()
# Out:
# id                      499.500
# rok_produkcji          2009.009
# pojemnosc_silnika      2040.065
# przebieg             132556.677
# cena                  51942.181
# dtype: float64

# %%
fury.mean(1)
# Out:
# 0      47902.8
# 1      44782.6
# 2      22481.2
# 3      21602.2
# 4      36262.0
#         ...
# 995    44258.2
# 996    14461.6
# 997    36642.4
# 998    47298.6
# 999    31100.2
# Length: 1000, dtype: float64

# %%
fury.apply(np.cumsum)
# Out:
#          id                                              marka  \
# 0         0                                             Nissan
# 1         1                                          NissanBMW
# 2         3                                      NissanBMWOpel
# 3         6                               NissanBMWOpelHyundai
# 4        10                     NissanBMWOpelHyundaiVolkswagen
# ..      ...                                                ...
# 995  495510  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 996  496506  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 997  497503  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 998  498501  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 999  499500  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
#
#                                                  model  rok_produkcji  \
# 0                                          X-Trail III         2014.0
# ...

# %%
pieces = [fury[:3], fury[3:7], fury[7:]]

# %%
pieces
# Out:
# [   id   marka        model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
#  0   0  Nissan  X-Trail III         2014.0         Diesel             1600.0
#  1   1     BMW       X1 E84         2012.0         Diesel             2000.0
#  2   2    Opel     Zafira A         2004.0    Benzyna+CNG             1600.0
#
#     przebieg     cena     wojewodztwo
#  0  160000.0  75900.0    Dolnośląskie
#  1  149000.0  70900.0  Świętokrzyskie
#  2   99000.0   9800.0        Opolskie  ,
#     id       marka      model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
#  3   3     Hyundai      i10 I         2008.0        Benzyna             1100.0
#  4   4  Volkswagen         CC         2010.0         Diesel             1968.0
#  5   5        Fiat        500         2014.0    Elektryczny                1.0
#  6   6      Nissan  X-Trail I         2004.0         Diesel             2200.0
#
#     przebieg     cena    wojewodztwo
#  3   93000.0  11900.0        Łódzkie
# ...

# %%
pd.concat(pieces)
# Out:
#       id       marka        model  rok_produkcji rodzaj_silnika  \
# 0      0      Nissan  X-Trail III         2014.0         Diesel
# 1      1         BMW       X1 E84         2012.0         Diesel
# 2      2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3      3     Hyundai        i10 I         2008.0        Benzyna
# 4      4  Volkswagen           CC         2010.0         Diesel
# ..   ...         ...          ...            ...            ...
# 995  995  Alfa Romeo          159         2009.0         Diesel
# 996  996       Škoda     Fabia II         2012.0        Benzyna
# 997  997     Renault        Modus         2004.0        Benzyna
# 998  998        Audi        A3 8L         2000.0        Benzyna
# 999  999       Volvo      XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# 0               1600.0  160000.0   75900.0    Dolnośląskie
# 1               2000.0  149000.0   70900.0  Świętokrzyskie
# ...

# %%
s = fury.iloc[3]

# %%
fury.append(s, ignore_index=True)
# Out:
#        id       marka        model  rok_produkcji rodzaj_silnika  \
# 0       0      Nissan  X-Trail III         2014.0         Diesel
# 1       1         BMW       X1 E84         2012.0         Diesel
# 2       2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3       3     Hyundai        i10 I         2008.0        Benzyna
# 4       4  Volkswagen           CC         2010.0         Diesel
# ...   ...         ...          ...            ...            ...
# 996   996       Škoda     Fabia II         2012.0        Benzyna
# 997   997     Renault        Modus         2004.0        Benzyna
# 998   998        Audi        A3 8L         2000.0        Benzyna
# 999   999       Volvo      XC 60 I         2016.0         Diesel
# 1000    3     Hyundai        i10 I         2008.0        Benzyna
#
#       pojemnosc_silnika  przebieg      cena     wojewodztwo
# 0                1600.0  160000.0   75900.0    Dolnośląskie
# 1                2000.0  149000.0   70900.0  Świętokrzyskie
# ...

# %%
s
# Out:
# id                         3
# marka                Hyundai
# model                  i10 I
# rok_produkcji           2008
# rodzaj_silnika       Benzyna
# pojemnosc_silnika       1100
# przebieg               93000
# cena                   11900
# wojewodztwo          Łódzkie
# Name: 3, dtype: object

# %%
fury.groupby('cena').sum()
# Out:
#            id  rok_produkcji  pojemnosc_silnika  przebieg
# cena
# 650.0     249         2000.0              796.0  188200.0
# 899.0     626         1997.0             1300.0  219000.0
# 900.0     497         1998.0             1400.0  136000.0
# 1900.0    321         1998.0             1043.0  137153.0
# 2200.0    487         2002.0             1299.0  282000.0
# ...       ...            ...                ...       ...
# 469900.0  410         2017.0             2000.0   10000.0
# 514000.0  517         2016.0             3993.0   10000.0
# 529900.0  855         2016.0             4999.0   20000.0
# 579000.0  586         2013.0             5500.0    4900.0
# 616000.0  405         2016.0             4663.0    2000.0
#
# [516 rows x 4 columns]

# %%
fury.groupby(['cena','przebieg']).sum()
# Out:
#                     id  rok_produkcji  pojemnosc_silnika
# cena     przebieg
# 650.0    188200.0  249         2000.0              796.0
# 899.0    219000.0  626         1997.0             1300.0
# 900.0    136000.0  497         1998.0             1400.0
# 1900.0   137153.0  321         1998.0             1043.0
# 2200.0   282000.0  487         2002.0             1299.0
# ...                ...            ...                ...
# 469900.0 10000.0   410         2017.0             2000.0
# 514000.0 10000.0   517         2016.0             3993.0
# 529900.0 20000.0   855         2016.0             4999.0
# 579000.0 4900.0    586         2013.0             5500.0
# 616000.0 2000.0    405         2016.0             4663.0
#
# [997 rows x 3 columns]

# %%
stacked=fury.stack()

# %%
stacked
# Out:
# 0    id                             0
#      marka                     Nissan
#      model                X-Trail III
#      rok_produkcji               2014
#      rodzaj_silnika            Diesel
#                              ...
# 999  rodzaj_silnika            Diesel
#      pojemnosc_silnika           1969
#      przebieg                   13617
#      cena                      136900
#      wojewodztwo          Małopolskie
# Length: 9000, dtype: object

# %%
stacked.unstack()
# Out:
#       id       marka        model rok_produkcji rodzaj_silnika  \
# 0      0      Nissan  X-Trail III          2014         Diesel
# 1      1         BMW       X1 E84          2012         Diesel
# 2      2        Opel     Zafira A          2004    Benzyna+CNG
# 3      3     Hyundai        i10 I          2008        Benzyna
# 4      4  Volkswagen           CC          2010         Diesel
# ..   ...         ...          ...           ...            ...
# 995  995  Alfa Romeo          159          2009         Diesel
# 996  996       Škoda     Fabia II          2012        Benzyna
# 997  997     Renault        Modus          2004        Benzyna
# 998  998        Audi        A3 8L          2000        Benzyna
# 999  999       Volvo      XC 60 I          2016         Diesel
#
#     pojemnosc_silnika przebieg    cena     wojewodztwo
# 0                1600   160000   75900    Dolnośląskie
# 1                2000   149000   70900  Świętokrzyskie
# ...

# %%
stacked.unstack(0)
# Out:
#                             0               1            2        3    \
# id                            0               1            2        3
# marka                    Nissan             BMW         Opel  Hyundai
# model               X-Trail III          X1 E84     Zafira A    i10 I
# rok_produkcji              2014            2012         2004     2008
# rodzaj_silnika           Diesel          Diesel  Benzyna+CNG  Benzyna
# pojemnosc_silnika          1600            2000         1600     1100
# przebieg                 160000          149000        99000    93000
# cena                      75900           70900         9800    11900
# wojewodztwo        Dolnośląskie  Świętokrzyskie     Opolskie  Łódzkie
#
#                              4            5             6          7    \
# id                             4            5             6          7
# marka                 Volkswagen         Fiat        Nissan       Seat
# ...

# %%
pd.pivot_table(fury, values='cena', index=['marka', 'przebieg'], columns=['model'])
# Out:
# model                   147     156      159  2 I  2 III  2008  206  206 CC  \
# marka      przebieg
# Alfa Romeo 175000.0     NaN     NaN      NaN  NaN    NaN   NaN  NaN     NaN
#            182000.0     NaN     NaN  33900.0  NaN    NaN   NaN  NaN     NaN
#            190000.0     NaN     NaN  19000.0  NaN    NaN   NaN  NaN     NaN
#            200000.0  4100.0     NaN      NaN  NaN    NaN   NaN  NaN     NaN
#            284000.0     NaN  6900.0      NaN  NaN    NaN   NaN  NaN     NaN
# ...                     ...     ...      ...  ...    ...   ...  ...     ...
# Škoda      182315.0     NaN     NaN      NaN  NaN    NaN   NaN  NaN     NaN
#            185000.0     NaN     NaN      NaN  NaN    NaN   NaN  NaN     NaN
#            186000.0     NaN     NaN      NaN  NaN    NaN   NaN  NaN     NaN
#            199000.0     NaN     NaN      NaN  NaN    NaN   NaN  NaN     NaN
#            214000.0     NaN     NaN      NaN  NaN    NaN   NaN  NaN     NaN
#
# ...

# %%
fury["markaa"] = fury["marka"].astype("category")

# %%
fury["markaa"]
# Out:
# 0          Nissan
# 1             BMW
# 2            Opel
# 3         Hyundai
# 4      Volkswagen
#           ...
# 995    Alfa Romeo
# 996         Škoda
# 997       Renault
# 998          Audi
# 999         Volvo
# Name: markaa, Length: 1000, dtype: category
# Categories (43, object): [Alfa Romeo, Audi, BMW, Chevrolet, ..., Toyota, Volkswagen, Volvo, Škoda]

# %%
fury.sort_values(by="markaa")
# Out:
#       id       marka       model  rok_produkcji rodzaj_silnika  \
# 370  370  Alfa Romeo         159         2007.0         Diesel
# 300  300  Alfa Romeo         147         2002.0        Benzyna
# 705  705  Alfa Romeo      Spider         1995.0    Benzyna+LPG
# 213  213  Alfa Romeo         156         2004.0         Diesel
# 995  995  Alfa Romeo         159         2009.0         Diesel
# ..   ...         ...         ...            ...            ...
# 313  313       Škoda    Fabia II         2013.0         Diesel
# 733  733       Škoda  Octavia II         2010.0        Benzyna
# 978  978       Škoda    Fabia II         2014.0         Diesel
# 346  346       Škoda     Fabia I         2002.0        Benzyna
# 319  319       Škoda  Octavia II         2006.0        Benzyna
#
#      pojemnosc_silnika  przebieg     cena    wojewodztwo      markaa
# 370             1900.0  190000.0  19000.0    Mazowieckie  Alfa Romeo
# 300             2000.0  200000.0   4100.0      Lubelskie  Alfa Romeo
# ...

# %%
fury.groupby("markaa").size()
# Out:
# markaa
# Alfa Romeo         5
# Audi              70
# BMW               66
# Chevrolet         11
# Chrysler           1
# Citroën           40
# Dacia              5
# Daewoo             2
# Daihatsu           1
# Dodge              5
# Fiat              33
# Ford              59
# Honda             25
# Hyundai           31
# Infiniti           2
# Jaguar             2
# Jeep               6
# Kia               25
# Lancia             1
# Land Rover         5
# Lexus              7
# Ligier             1
# Maserati           1
# Mazda             21
# Mercedes-Benz     59
# Mini              11
# Mitsubishi        18
# Nissan            33
# Opel             105
# Peugeot           41
# Pontiac            1
# Porsche            2
# Renault           59
# Saab               3
# Seat              20
# Smart              2
# SsangYong          3
# Subaru             1
# Suzuki            16
# Toyota            49
# Volkswagen        92
# Volvo             24
# Škoda             36
# ...

# %%
ts = pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000', periods=1000))

# %%
ts=ts.cumsum()

# %%
fury.cumsum()
# Out:
#          id                                              marka  \
# 0         0                                             Nissan
# 1         1                                          NissanBMW
# 2         3                                      NissanBMWOpel
# 3         6                               NissanBMWOpelHyundai
# 4        10                     NissanBMWOpelHyundaiVolkswagen
# ..      ...                                                ...
# 995  495510  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 996  496506  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 997  497503  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 998  498501  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 999  499500  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
#
#                                                  model rok_produkcji  \
# 0                                          X-Trail III          2014
# ...

# %%
fury.to_csv('fury.csv')

# %%
pd.read_csv('fury.csv')
# Out:
#      Unnamed: 0   id       marka        model  rok_produkcji rodzaj_silnika  \
# 0             0    0      Nissan  X-Trail III         2014.0         Diesel
# 1             1    1         BMW       X1 E84         2012.0         Diesel
# 2             2    2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3             3    3     Hyundai        i10 I         2008.0        Benzyna
# 4             4    4  Volkswagen           CC         2010.0         Diesel
# ..          ...  ...         ...          ...            ...            ...
# 995         995  995  Alfa Romeo          159         2009.0         Diesel
# 996         996  996       Škoda     Fabia II         2012.0        Benzyna
# 997         997  997     Renault        Modus         2004.0        Benzyna
# 998         998  998        Audi        A3 8L         2000.0        Benzyna
# 999         999  999       Volvo      XC 60 I         2016.0         Diesel
#
# ...
